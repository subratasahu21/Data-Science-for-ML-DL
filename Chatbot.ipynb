# %%
pip install transformers torch datasets opencv-python pillow
# Out:
# ...
#      ---------------------------------------- 0.0/43.8 kB ? eta -:--:--
#      ------------------ --------------------- 20.5/43.8 kB ? eta -:--:--
#      ----------------------------------- -- 41.0/43.8 kB 393.8 kB/s eta 0:00:01
#      -------------------------------------- 43.8/43.8 kB 361.0 kB/s eta 0:00:00
# ...
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# ...
#      ---------------------------------------- 0.0/57.6 kB ? eta -:--:--
#      ---------------------------------------- 57.6/57.6 kB 1.0 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/9.1 MB ? eta -:--:--
#     --------------------------------------- 0.1/9.1 MB 4.3 MB/s eta 0:00:03
#    - -------------------------------------- 0.4/9.1 MB 5.1 MB/s eta 0:00:02
#    --- ------------------------------------ 0.8/9.1 MB 6.4 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.3/9.1 MB 7.4 MB/s eta 0:00:02
#    ------- -------------------------------- 1.8/9.1 MB 8.3 MB/s eta 0:00:01
# ...
